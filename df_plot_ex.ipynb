# %% [markdown]
# <a href="https://colab.research.google.com/github/Azzziii/Rubikamp-Data-Science-Course/blob/main/df_plot_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4004292b-46d0-4013-91d7-5f1bf5cf3648" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4004292b-46d0-4013-91d7-5f1bf5cf3648">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5892 entries, 0 to 5891
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5892 non-null   object
#  1   Salary Estimate    5892 non-null   object
#  2   Rating             5892 non-null   float64
#  3   Company Name       5892 non-null   object
#  4   Location           5892 non-null   object
#  5   Size               5892 non-null   object
#  6   Founded            5892 non-null   object
#  7   Type of ownership  5892 non-null   object
#  8   Industry           5892 non-null   object
#  9   Sector             5892 non-null   object
#  10  Revenue            5892 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 506.5+ KB

# %%
ownership =df['Type of ownership'].value_counts()
ownership
# Out:
# Company - Private                 2666
# Company - Public                  1776
# -1                                 541
# Nonprofit Organization             309
# Subsidiary or Business Segment     257
# College / University               109
# Government                         102
# Unknown                             44
# Hospital                            31
# Contract                            21
# Private Practice / Firm             18
# Self-employed                        6
# School / School District             5
# Other Organization                   5
# Franchise                            1
# Unknown / Non-Applicable             1
# Name: Type of ownership, dtype: int64

# %%
ownership.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Founded'].value_counts().plot()
# Out:
# <Axes: >

# %%
df5 = df[df['Founded']!='Unknown']

# %%
df5['Founded'] = df5['Founded'].astype(int)
# Out:
# <ipython-input-44-cf85d5f251a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['Founded'] = df5['Founded'].astype(int)

# %%
df5['Founded'].plot.hist(bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Type of ownership'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Founded'].value_counts()
# Out:
# -1         1304
# 1994        152
# 1999        145
# 2002        130
# 2015        128
#            ...
# Unknown       1
# 1873          1
# 1842          1
# 1682          1
# 1809          1
# Name: Founded, Length: 204, dtype: int64

# %%
df['Rating'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
income = df['Revenue'].value_counts()
income
# Out:
# Unknown / Non-Applicable            1504
# $10+ billion (USD)                  1002
# -1                                   562
# $100 to $500 million (USD)           475
# $2 to $5 billion (USD)               358
# $1 to $2 billion (USD)               295
# $50 to $100 million (USD)            292
# $5 to $10 billion (USD)              285
# $10 to $25 million (USD)             262
# $25 to $50 million (USD)             214
# $1 to $5 million (USD)               207
# $500 million to $1 billion (USD)     162
# Less than $1 million (USD)           139
# $5 to $10 million (USD)              135
# Name: Revenue, dtype: int64

# %%
income.plot(kind='bar', color = 'grey')
# Out:
# <Axes: >

# %%
df['Size'].unique()
# Out:
# array(['501 to 1000 employees', '1001 to 5000 employees',
#        '1 to 50 employees', '201 to 500 employees', '51 to 200 employees',
#        '10000+ employees', '5001 to 10000 employees', 'Unknown', '-1',
#        '5001 to 10000 Employees', '10000+ Employees',
#        '501 to 1000 Employees', '201 to 500 Employees',
#        '1001 to 5000 Employees', '51 to 200 Employees',
#        '1 to 50 Employees'], dtype=object)

# %%
df['Size'].value_counts()
# Out:
# 10000+ employees           993
# 10000+ Employees           674
# 51 to 200 employees        563
# 1001 to 5000 employees     553
# 1 to 50 employees          550
# -1                         541
# 201 to 500 employees       418
# 501 to 1000 employees      307
# 51 to 200 Employees        228
# 1001 to 5000 Employees     221
# 5001 to 10000 employees    219
# 5001 to 10000 Employees    183
# 201 to 500 Employees       161
# 501 to 1000 Employees      104
# 1 to 50 Employees           92
# Unknown                     85
# Name: Size, dtype: int64

# %%
df['Size'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Sector'].value_counts()
# Out:
# Information Technology                1516
# Business Services                     1013
# -1                                     876
# Biotech & Pharmaceuticals              449
# Finance                                382
# Health Care                            296
# Manufacturing                          212
# Insurance                              187
# Education                              142
# Aerospace & Defense                    126
# Government                             109
# Media                                  103
# Retail                                 103
# Accounting & Legal                      99
# Oil, Gas, Energy & Utilities            50
# Telecommunications                      38
# Transportation & Logistics              36
# Consumer Services                       29
# Non-Profit                              28
# Construction, Repair & Maintenance      22
# Real Estate                             21
# Restaurants, Bars & Food Services       16
# ...

# %%
df['Sector'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
